# %%
from openai import OpenAI

# %%
import pandas as pd
import os
import time

# %%
#print (OPENAI_API_KEY)

# %%
def load_csv(path):
    # Load the CSV file into a DataFrame
    df = pd.read_csv(path, header=0)
    print(df)
    
    return (df)

# %%
df = load_csv("C:\\e\\a2_generated_sites\\articles.csv")
# Out:
#    category generate                site  \
# 0  festival        n  happy-new-year.org
# 1  festival        n  happy-new-year.org
# 2  festival        y  happy-new-year.org
# 3  festival        y  happy-new-year.org
#
#                                          article_dir  \
# 0  c:\e\a2_generated_sites\1-articles-festivals\f...
# 1  c:\e\a2_generated_sites\1-articles-festivals\f...
# 2  c:\e\a2_generated_sites\1-articles-festivals\f...
# 3  c:\e\a2_generated_sites\1-articles-festivals\f...
#
#                                           input_path  \
# 0  c:\e\a3_input\happy-new-year.org\input\content...
# 1  c:\e\a3_input\happy-new-year.org\input\content...
# 2    c:\e\a3_input\happy-new-year.org\input\content\
# 3    c:\e\a3_input\happy-new-year.org\input\content\
#
#                    filename                                             prompt
# 0             things-to-buy  What are best deals for Black Friday. What thi...
# 1         things-not-to-buy  What kindof things one should avoid buying on ...
# 2          chinese-new-year  Describe significance of chinese new year. Whe...
# 3  chinese-new-year-history  Describe history of chinese new year? How do p...

# %%
'''

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
      
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

def get_completion4(prompt, model="gpt-4"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]
    
'''
# Out:
# '\n\ndef get_completion(prompt, model="gpt-3.5-turbo"):\n    messages = [{"role": "user", "content": prompt}]\n      \n    response = openai.ChatCompletion.create(\n        model=model,\n        messages=messages,\n        temperature=0, # this is the degree of randomness of the model\'s output\n    )\n    return response.choices[0].message["content"]\n\ndef get_completion4(prompt, model="gpt-4"):\n    messages = [{"role": "user", "content": prompt}]\n    response = openai.ChatCompletion.create(\n        model=model,\n        messages=messages,\n        temperature=0, # this is the degree of randomness of the model\'s output\n    )\n    return response.choices[0].message["content"]\n    \n'

# %%
def check_exist(filename):
    if (os.path.isfile(filename)):
        print ("Exist ", filename)
        return True
    else:
        return False

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    
    client = OpenAI(api_key="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")
    
    #client.api_key = "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"
    #openai.api_key = "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"
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

def get_completion4(prompt, model="gpt-4"):
    messages = [{"role": "user", "content": prompt}]
    
    client = OpenAI(api_key="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")
    
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content


def get_completion4a(prompt, model="gpt-4-1106-preview"):
    messages = [{"role": "user", "content": prompt}]
    
    client = OpenAI(api_key="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")
    
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message.content

# %%
def write_files(topic, prompt, answer, filename):
    

    #name = topic + "-main"
    #name = topic + "-road-trip"
    #name = topic + "-summer-vacation"
    #name = topic + "-museums"
    #name = topic + "-amusement-parks"
    
    
    article_path = root + local_articles + subpath_windows + filename
    directory = root + local_articles + subpath_windows
   
    
    filename1 = article_path + ".txt"
    filenamep = article_path + ".prompt"
    
    print (filename1)
    
    if not os.path.exists(directory):
    # If it doesn't exist, create it
        os.makedirs(directory)
    
    
    if (check_exist(filename1)):
        print ("Already exist ", filename1) 
    else:
        # write .txt, .htm    
        with open (filename1, 'w+') as f:
            #f.write(prompt)
            #f.write('\n')
            f.writelines(answer)
            
        f.close()
            
            
        with open (filenamep, 'w+') as fp:
            #f.write(prompt)
            #f.write('\n')
            fp.writelines(prompt)
        fp.close()
    
    '''
    creating directory with article name
    if not os.path.exists(article_path):
        os.makedirs(article_path)
        print ("created path",article_path )
        
    '''

    # write .articlelist
    filename2 = article_path + ".articlelist"
    filename2_text = filename1
    
    print ("filename 2", filename2,root , local_articles , subpath_windows , filename )
        
    if (check_exist(filename2)):
        print ("Already exist ", filename2) 
    else:  
        with open (filename2, 'w') as f2:
            f2.write(filename2_text)
        f2.close()
    
    
    # articlelist for site, other files for sites
    #filename3 = "/Users/prashantkdhingra/kreate/a3_input_clean/" + website + "/" + "input/content/blog/"+ name + ".articlelist"
    html_page_path = root + local_input + website_windows  + "input\\content\\"+ subsite_windows
    article_page = html_page_path + filename
    filename3 =  article_page + ".articlelist"
    
    
    if not os.path.exists(html_page_path):
        os.makedirs(html_page_path)
        print ("created path 2",html_page_path)
    
    print ("filename 3", filename3,  root + local_input + website_windows , subsite_windows)
    
    if (check_exist(filename3)):
        print ("Already exist ", filename3) 
    else:
        filename3_text =  filename2 
        with open (filename3,'w+') as f3:
            f3.write(filename3_text)
            f3.write('\n')
        f3.close()
    
        filename3_title = article_page + ".title"
        filename3_keywords =  article_page + ".keywords"
        filename3_desc =  article_page + ".desc"
        filename3_url = article_page + ".articleurl"
    #print (filename3)
    

    
    
        with open (filename3_url,'w+') as fu:
            fu.write(filename)
            fu.write('\n')
        fu.close()
    
    
    
        prompt_desc = f"""
        Your task is to write a catchy title of less than 50 characters. Write it in plain text \

        Review: ```{answer}```
        """
    
        time.sleep(30)
        title = get_completion(prompt_desc)
        print(title)

        # write title
        with open (filename3_title,'w+') as ft:
            ft.write(title)
            #ft.write('\n')
        ft.close()
    
        prompt_desc = f"""
        Your task is to generate a summary sentence of  article \
        Write a 2 line summary of article. 

        Summarize the article , delimited by triple 
        backticks, in at most 160 words. Write it as plain text

        Review: ```{answer}```
        """

        time.sleep(30)
        desc = get_completion(prompt_desc)
        print(desc)
    
        with open (filename3_desc,'w+') as fd:
            fd.write(desc)
            #fd.write('\n')
            fd.close()
    
        time.sleep(20)
    
    
        prompt_topics = f"""
        Determine ten topics that are being discussed in the \
        following text, which is delimited by triple backticks.

        Make each item one or two words long. 

        Format your response as a list of items separated by commas.

        Text sample: '''{answer}'''
        """
        keywords = get_completion(prompt_topics)
        print(keywords)
    
        with open (filename3_keywords,'w+') as fk:
            fk.write(keywords)
            fk.write('\n')
        fk.close()

# %%
def write_files_csv( article_dir, input_path, prompt, answer, filename):
    


    
    
    article_path = article_dir + filename
    #directory = root + local_articles + subpath_windows
    directory = article_dir
    
    filename1 = article_path + ".txt"
    filenamep = article_path + ".prompt"
    
    print (filename1)
    
    if not os.path.exists(directory):
    # If it doesn't exist, create it
        os.makedirs(directory)
    
    
    if (check_exist(filename1)):
        print ("Already exist ", filename1) 
    else:
        # write .txt, .htm    
        with open (filename1, 'w+') as f:
            #f.write(prompt)
            #f.write('\n')
            f.writelines(answer)
            
        f.close()
            
            
        with open (filenamep, 'w+') as fp:
            #f.write(prompt)
            #f.write('\n')
            fp.writelines(prompt)
        fp.close()
    
    '''
    creating directory with article name
    if not os.path.exists(article_path):
        os.makedirs(article_path)
        print ("created path",article_path )
        
    '''

    # write .articlelist
    filename2 = article_path + ".articlelist"
    filename2_text = filename1
    
    print ("filename 2", filename2 )
        
    if (check_exist(filename2)):
        print ("Already exist ", filename2, filename2_text) 
    else:  
        with open (filename2, 'w') as f2:
            f2.write(filename2_text)
        f2.close()
    
    
    # html_page_path = root + local_input + website_windows  + "input\\content\\"+ subsite_windows
    

    html_page_path = input_path    
    article_page = html_page_path + filename
    filename3 =  article_page + ".articlelist"
    
    
    if not os.path.exists(html_page_path):
        os.makedirs(html_page_path)
        print ("created path 2",html_page_path)
    
    #print ("filename 3", filename3,  root + local_input + website_windows , subsite_windows)
    print ("filename 3", filename3)
    
    if (check_exist(filename3)):
        print ("Already exist ", filename3) 
    else:
        filename3_text =  filename2 
        with open (filename3,'w+') as f3:
            f3.write(filename3_text)
            f3.write('\n')
        f3.close()
    
        filename3_title = article_page + ".title"
        filename3_keywords =  article_page + ".keywords"
        filename3_desc =  article_page + ".desc"
        filename3_url = article_page + ".articleurl"
    #print (filename3)
    

    
    
        with open (filename3_url,'w+') as fu:
            fu.write(filename)
            fu.write('\n')
        fu.close()
    
    
    
        prompt_desc = f"""
        Your task is to write a catchy title of less than 50 characters \

        Review: ```{answer}```
        """
    
        time.sleep(30)
        title = get_completion(prompt_desc)
        print(title)

        # write title
        with open (filename3_title,'w+') as ft:
            ft.write(title)
            #ft.write('\n')
        ft.close()
    
        prompt_desc = f"""
        Your task is to generate a summary sentence of tour article \
        Write a 2 line summary of article. 

        Summarize the article below, delimited by triple 
        backticks, in at most 160 words. 

        Review: ```{answer}```
        """

        time.sleep(30)
        desc = get_completion(prompt_desc)
        print(desc)
    
        with open (filename3_desc,'w+') as fd:
            fd.write(desc)
            #fd.write('\n')
            fd.close()
    
        time.sleep(20)
    
    
        prompt_topics = f"""
        Determine ten topics that are being discussed in the \
        following text, which is delimited by triple backticks.

        Make each item one or two words long. 

        Format your response as a list of items separated by commas.

        Text sample: '''{answer}'''
        """
        keywords = get_completion(prompt_topics)
        print(keywords)
    
        with open (filename3_keywords,'w+') as fk:
            fk.write(keywords)
            fk.write('\n')
        fk.close()

# %%
openai.api_key = "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"

# use below to test gpt4
openai.api_key ="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"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 openai.api_key = "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"
#       3 # use below to test gpt4
#       4 openai.api_key ="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"
#
# NameError: name 'openai' is not defined

# %%
instruction =  f"""
Format everything as HTML table that can be used in a website. 
Place the description in a <div> element.
Do not write in beginning end that there is a HTML tab.  Content should be ready to present in website
"""

# %%
#df = load_csv("C:\\e\\a2_generated_sites\\articles.csv")
df = load_csv("C:\\e\\kreate\\chatgpt2\\articles.csv")
# Out:
#     category generate                site  \
# 0   festival        y  makarsankranti.org
# 1   festival        y  makarsankranti.org
# 2   festival        y  makarsankranti.org
# 3   festival        y  makarsankranti.org
# 4   festival        y  makarsankranti.org
# 5   festival        y  makarsankranti.org
# 6   festival        y  makarsankranti.org
# 7   festival        y  makarsankranti.org
# 8   festival        y  makarsankranti.org
# 9   festival        y  makarsankranti.org
# 10  festival        y  makarsankranti.org
# 11  festival        y  makarsankranti.org
# 12  festival        v  makarsankranti.org
# 13  festival        v  makarsankranti.org
# 14  festival        v  makarsankranti.org
# 15  festival        v  makarsankranti.org
# 16  festival        v  makarsankranti.org
# 17  festival        v  makarsankranti.org
#
#                                           article_dir  \
# 0   c:\e\a2_generated_sites\1-articles-festivals\s...
# 1   c:\e\a2_generated_sites\1-articles-festivals\s...
# 2   c:\e\a2_generated_sites\1-articles-festivals\s...
# 3   c:\e\a2_generated_sites\1-articles-festivals\s...
# 4   c:\e\a2_generated_sites\1-articles-festivals\s...
# 5   c:\e\a2_generated_sites\1-articles-festivals\s...
# 6   c:\e\a2_generated_sites\1-articles-festivals\s...
# 7   c:\e\a2_generated_sites\1-articles-festivals\s...
# 8   c:\e\a2_generated_sites\1-articles-festivals\s...
# 9   c:\e\a2_generated_sites\1-articles-festivals\s...
# 10  c:\e\a2_generated_sites\1-articles-festivals\s...
# 11  c:\e\a2_generated_sites\1-articles-festivals\s...
# 12  c:\e\a2_generated_sites\1-articles-festivals\s...
# 13  c:\e\a2_generated_sites\1-articles-festivals\s...
# 14  c:\e\a2_generated_sites\1-articles-festivals\s...
# 15  c:\e\a2_generated_sites\1-articles-festivals\s...
# 16  c:\e\a2_generated_sites\1-articles-festivals\s...
# 17  c:\e\a2_generated_sites\1-articles-festivals\s...
#
#                                            input_path  filename  \
# 0   c:\e\a3_input\makarsankranti.org\input\content...     hindi
# 1   c:\e\a3_input\makarsankranti.org\input\content...     tamil
# 2   c:\e\a3_input\makarsankranti.org\input\content...    telugu
# 3   c:\e\a3_input\makarsankranti.org\input\content...   kannada
# 4   c:\e\a3_input\makarsankranti.org\input\content...   marathi
# 5   c:\e\a3_input\makarsankranti.org\input\content...  gujarati
# 6   c:\e\a3_input\makarsankranti.org\input\content...   bengali
# 7   c:\e\a3_input\makarsankranti.org\input\content...  bhojpuri
# 8   c:\e\a3_input\makarsankranti.org\input\content...  assamese
# 9   c:\e\a3_input\makarsankranti.org\input\content...  nepalese
# 10  c:\e\a3_input\makarsankranti.org\input\content...   punjabi
# 11  c:\e\a3_input\makarsankranti.org\input\content...    bihari
# 12  c:\e\a3_input\makarsankranti.org\input\content...    sindhi
# 13  c:\e\a3_input\makarsankranti.org\input\content...  malyalam
# 14  c:\e\a3_input\makarsankranti.org\input\content...   english
# 15  c:\e\a3_input\makarsankranti.org\input\content...  kashmiri
# 16  c:\e\a3_input\makarsankranti.org\input\content...      urdu
# 17  c:\e\a3_input\makarsankranti.org\input\content...  sanskrit
#
#                                                prompt
# 0   Write 20 beautiful wishes for Sankranti in hin...
# 1   Write 20 beautiful wishes for Sankranti in tam...
# 2   Write 20 beautiful wishes for Sankranti in tel...
# 3   Write 20 beautiful wishes for Sankranti in kan...
# 4   Write 20 beautiful wishes for Sankranti in mar...
# 5   Write 20 beautiful wishes for Sankranti in guj...
# 6   Write 20 beautiful wishes for Sankranti in ben...
# 7   Write 20 beautiful wishes for Sankranti in bho...
# 8   Write 20 beautiful wishes for Sankranti in ass...
# 9   Write 20 beautiful wishes for Sankranti in nep...
# 10  Write 20 beautiful wishes for Sankranti in puj...
# 11  Write 20 beautiful wishes for Sankranti and Bi...
# 12  Write 20 beautiful wishes for Sankranti in sin...
# 13  Write 20 beautiful wishes for Sankranti in mal...
# 14  Write 20 beautiful wishes for Sankranti in eng...
# 15  Write 20 beautiful wishes for Sankranti in kas...
# 16  Write 20 beautiful wishes for Sankranti and Bi...
# 17  Write 20 beautiful wishes for Sankranti in san...

# %%
i = 0 ;
for row in df.iterrows():
    #print(row)
    
    
    prompt_raw=df.iloc[i].prompt
    prompt = prompt_raw + instruction
    article_dir = df.iloc[i].article_dir
    input_path = df.iloc[i].input_path
    filename = df.iloc[i].filename
    generate = df.iloc[i].generate
    
    print ("generate = " , generate)
    #print (article_dir, input_path, filename, prompt)

    
    if (generate == 'y'):
        print (article_dir, input_path, filename, prompt)
        
        time.sleep(30)
        
        #answer = get_completion4(prompt)
        #answer = get_completion(prompt)
        
        #answer1 = get_completion4(prompt)
        #print (answer)
        
        answer = get_completion4a(prompt)
        print(answer)
        
        time.sleep(30)
        write_files_csv(article_dir, input_path, prompt, answer, filename)
        time.sleep(30)
        
    
    i = i + 1
# Out:
# generate =  y
# c:\e\a2_generated_sites\1-articles-festivals\sankranti\wishes\ c:\e\a3_input\makarsankranti.org\input\content\wishes\ hindi Write 20 beautiful wishes for Sankranti in hindi language
# Format everything as HTML table that can be used in a website.
# Place the description in a <div> element.
# Do not write in beginning end that there is a HTML tab.  Content should be ready to present in website
#
# ```html
# <table>
#   <tr>
#     <th>Sankranti Wishes</th>
#   </tr>
#   <tr>
#     <td><div>1. संक्रांति के इस पावन पर्व पर, आपके जीवन में सुख, समृद्धि और आनंद का आगमन हो।</div></td>
#   </tr>
#   <tr>
#     <td><div>2. आपको और आपके परिवार को मकर संक्रांति की हार्दिक शुभकामनाएँ।</div></td>
#   </tr>
#   <tr>
#     <td><div>3. इस संक्रांति पर भगवान सूर्य आपके जीवन को रोशन करें।</div></td>
#   </tr>
#   <tr>
#     <td><div>4. पतंगों की तरह आपके सपने भी उच्चाईयों को छूएं, संक्रांति की शुभकामनाएँ।</div></td>
#   </tr>
#   <tr>
#     <td><div>5. मीठे गुड़ में मिल गए तिल, उड़ी पतंग और खिल गए दिल। संक्रांति की बधाई।</div></td>
#   </tr>
#   <tr>
#     <td><div>6. संक्रांति का त्योहार आपके जीवन में नई ऊर्जा और उत्साह भर दे।</div></td>
#   </tr>
#   <tr>
#     <td><div>7. आपके जीवन का हर दिन संक्रांति की तरह खुशियों से भरा हो।</div></td>
#   </tr>
#   <tr>
#     <td><div>8. संक्रांति के इस शुभ अवसर पर, आपके सभी दुःख दूर हों।</div></td>
#   </tr>
#   <tr>
#     <td><div>9. तिलकुट और पतंगों के साथ, आपकी संक्रांति मंगलमय हो।</div></td>
#   </tr>
#   <tr>
#     <td><div>10. संक्रांति के इस मंगल पर्व पर, आपको ढेर सारी खुशियाँ मिलें।</div></td>
#   </tr>
#   <tr>
#     <td><div>11. आपका और आपके परिवार का जीवन उत्तरायण की तरह उन्नति की ओर अग्रसर हो।</div></td>
#   </tr>
#   <tr>
#     <td><div>12. संक्रांति के इस पावन मौके पर, आपके घर में धन और यश की बरसात हो।</div></td>
#   </tr>
#   <tr>
#     <td><div>13. आपकी जिंदगी में संक्रांति के सूरज की तरह चमक आए।</div></td>
#   </tr>
#   <tr>
#     <td><div>14. खुशियों की पतंगें आसमान में उड़ाएं, संक्रांति पर आपको ढेरों बधाईयाँ।</div></td>
#   </tr>
#   <tr>
#     <td><div>15. संक्रांति के इस शुभ दिन पर, आपके सभी सपने सच हों।</div></td>
#   </tr>
#   <tr>
#     <td><div>16. आपके जीवन में संक्रांति के रंग भर जाएँ, और आपकी दुनिया खुशियों से भर जाए।</div></td>
#   </tr>
#   <tr>
#     <td><div>17. संक्रांति की शुभ बेला पर, आपके जीवन में नयी रोशनी आए।</div></td>
#   </tr>
#   <tr>
#     <td><div>18. आपको संक्रांति के इस पर्व पर, अपार खुशियाँ और समृद्धि मिले।</div></td>
#   </tr>
#   <tr>
#     <td><div>19. संक्रांति के इस उत्सव पर, आपका हर पल शुभ हो।</div></td>
#   </tr>
#   <tr>
#     <td><div>20. आपके जीवन में संक्रांति के सूर्य की तरह नई किरणें आएं, और आपका हर दिन खुशहाल हो।</div></td>
#   </tr>
# </table>
# ```
# c:\e\a2_generated_sites\1-articles-festivals\sankranti\wishes\hindi.txt
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[33], line 32
#      29     print(answer)
#      31     time.sleep(30)
# ---> 32     write_files_csv(article_dir, input_path, prompt, answer, filename)
#      33     time.sleep(30)
#      36 i = i + 1
#
# Cell In[10], line 28, in write_files_csv(article_dir, input_path, prompt, answer, filename)
#      23 else:
#      24     # write .txt, .htm
#      25     with open (filename1, 'w+') as f:
#      26         #f.write(prompt)
#      27         #f.write('\n')
# ---> 28         f.writelines(answer)
#      30     f.close()
#      33     with open (filenamep, 'w+') as fp:
#      34         #f.write(prompt)
#      35         #f.write('\n')
#
# File C:\ProgramData\anaconda3\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u0938' in position 0: character maps to <undefined>
